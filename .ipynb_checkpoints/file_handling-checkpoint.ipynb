# %% [markdown]
# # file handling with python
#
# #### Python has several functions for creating, reading, updating, and deleting files.

# %% [markdown]
# ![image.png](attachment:43029d60-e4fb-49e8-b9ca-8b0a23caa3d9.png)

# %%
f = open("demofile.txt","rt") # open("demofile.txt")   both are same
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = open("demofile.txt","rt")
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demofile.txt'

# %% [markdown]
# ### since there is no any preiously create file in our directory so it throws an error, so lets create a new file using "w".

# %%
f = open("demofile.txt","wt") # w = wrie and t specifies text file

# %%
f = open("demofile.txt","rt")

# %% [markdown]
# ### now we dont get any error in reading

# %% [markdown]
# ### now lets wrie to a file and then read it
# #### lets use append to write on already exisitng file that we recently created

# %%
f = open("demofile.txt","at")

# %%
f.write("Now i am able to wrtie any etxt to my file and its will be saved asap i hit enter")
# Out:
# 81

# %%
f.close() #its important to close a file after using it

# %% [markdown]
# #  now lets read the full file :

# %%
f = open("demofile.txt","rt")

print(f.read())
# Out:
# Now i am able to wrtie any etxt to my file and its will be saved asap i hit enter

# %% [markdown]
# # Read Only Parts of the File

# %%
f = open("demofile.txt")
print(f.read(10))
# Out:
# Now i am a

# %% [markdown]
# # Read Lines

# %%
f = open("demofile.txt")
print(f.readline())
# Out:
# Now i am able to wrtie any etxt to my file and its will be saved asap i hit enter

# %% [markdown]
# # By looping through the lines of the file, you can read the whole file, line by line:

# %%
file = open("demofile.txt")

for x in file:
    print(x)
# Out:
# Now i am able to wrtie any etxt to my file and its will be saved asap i hit enter

# %%
f.close()

# %% [markdown]
# ## Delete a File

# %% [markdown]
# # we use import os then we can delete a file

# %%
import os
os.remove("temp.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 import os
# ----> 2 os.remove("temp.txt")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'temp.txt'

# %% [markdown]
# ### since we throw an error , lets create a temp named file and then delete it

# %%
file = open("temp.txt","wt")
file.close()

# %%
import os
os.remove("temp.txt")

# %% [markdown]
# ## we know we just deleted a file but we didn't got any confirmation whether deleted or not, so lets create a function to inform us

# %%
f =  open("tempp.txt","wt")
f.close()

# %%
import os
if os.path.exists("tempp.txt"):
    os.remove("tempp.txt")
    print("file deleted successfully")
else:
    print("file not found")
# Out:
# file deleted successfully

# %% [markdown]
# ## Create and Delete Folder

# %%
import os

os.mkdir("temp")

# %%
import os

os.rmdir("temp")

# %% [markdown]
# NOTE : YOU CAN ONLY REMOVE EMPTY FOLDER USING RMDIR
